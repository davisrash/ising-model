# %%
from typing import Final

import numpy as np

from qiskit import QuantumCircuit

from lib import FFFT

# %%
NUM_SITES: Final[int] = 2**3

# %%
qc8 = QuantumCircuit(NUM_SITES)

qc8.compose(FFFT(NUM_SITES), inplace=True)
qc8.decompose(reps=1).draw("mpl")

# %%
qc4 = QuantumCircuit(NUM_SITES // 2)

qc4.compose(FFFT(NUM_SITES // 2), inplace=True)
qc4.decompose(reps=1).draw("mpl")
